# %% [markdown]
# <a href="https://colab.research.google.com/github/Wikanda-Hongboonmee/DWDM21/blob/main/Project_DWDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # pandas เป็น Package ที่ใช้เกี่ยวกับการจัดการข้อมูลที่เป็นตาราง , เรียกใช้โดยการ import แล้วตามด้วยชื่อ Package

# %%
from google.colab import drive  # เชื่อมต่อกับ google drive ที่เราเก็บข้อมูลไว้
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # เป็น package ที่เอาไว้จัดการไฟล์และเอาไว้ดูที่มาของไฟล์หรือ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATAPROJECT' 
data_straffic60 = pd.read_csv(os.path.join(path,'straffic60.csv')) # ไฟล์ที่เราต้องการ
data_straffic60 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#       ทางหลวงสาย  ตอนควบคุม  ...                         แขวงการทาง          จังหวัด
# 0              1        102  ...                         ขท.กรุงเทพ    กรุงเทพมหานคร
# 1              1        201  ...                        ขท.ปทุมธานี         ปทุมธานี
# 2              1        202  ...                        ขท.ปทุมธานี  พระนครศรีอยุธยา
# 3              1        300  ...                          ขท.อยุธยา  พระนครศรีอยุธยา
# 4              1        300  ...                          ขท.อยุธยา  พระนครศรีอยุธยา
# ...          ...        ...  ...                                ...              ...
# 2686        4347        100  ...                            ขท.ตรัง             ตรัง
# 2687        4348        100  ...                          ขท.กระบี่             ตรัง
# 2688        4349        100  ...      ขท.สุราษฎร์ธานีที่ 1 (พุนพิน)     สุราษฎร์ธานี
# 2689        4350        100  ...  ขท.สุราษฎร์ธานีที่ 2 (กาญจนดิษฐ์)     สุราษฎร์ธานี
# ...

# %%
data_straffic60.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#       ทางหลวงสาย  ตอนควบคุม  ...  แขวงการทาง  จังหวัด
# 0          False      False  ...       False    False
# 1          False      False  ...       False    False
# 2          False      False  ...       False    False
# 3          False      False  ...       False    False
# 4          False      False  ...       False    False
# ...          ...        ...  ...         ...      ...
# 2686       False      False  ...       False    False
# 2687       False      False  ...       False    False
# 2688       False      False  ...       False    False
# 2689       False      False  ...       False    False
# 2690       False      False  ...       False    False
#
# [2691 rows x 20 columns]

# %%
data_straffic60.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง
# Out:
# ทางหลวงสาย                              False
# ตอนควบคุม                               False
# ชื่อสายทาง                              False
# จุดสำรวจ                                False
# รถยนต์นั่ง (ไม่เกิน 7 คน)               False
# รถยนต์นั่ง (เกิน 7 คน)                  False
# รถโดยสารขนาดเล็ก                        False
# รถโดยสารขนาดกลาง                        False
# รถโดยสารขนาดใหญ่                        False
#    รถบรรทุกขนาดเล็ก    ( 4 ล้อ)         False
# รถบรรทุกขนาด 2 เพลา  (6 ล้อ)            False
#      รถบรรทุกขนาด 3 เพลา (10 ล้อ)       False
#    รถบรรทุกพ่วง  (มากกว่า 3 เพลา)       False
#    รถบรรทุกกึ่งพ่วง (มากกว่า 3 เพลา)    False
# รวม                                     False
#    % ของยานยนต์หนัก                     False
# จักรยาน 2 ล้อ และ จักรยาน 3 ล้อ         False
# สามล้อเครื่องและจักรยานยนต์             False
# แขวงการทาง                              False
# จังหวัด                                 False
# dtype: bool

# %%
data_straffic62 = pd.read_csv(os.path.join(path,'straffic62.csv')) # ไฟล์ที่เราต้องการ
data_straffic62 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#       ทางหลวงสาย  ตอนควบคุม  ...                        แขวงทางหลวง          จังหวัด
# 0              1        102  ...                         ขท.กรุงเทพ    กรุงเทพมหานคร
# 1              1        201  ...                        ขท.ปทุมธานี         ปทุมธานี
# 2              1        202  ...                        ขท.ปทุมธานี  พระนครศรีอยุธยา
# 3              1        300  ...                          ขท.อยุธยา  พระนครศรีอยุธยา
# 4              1        300  ...                          ขท.อยุธยา  พระนครศรีอยุธยา
# ...          ...        ...  ...                                ...              ...
# 2695        4347        100  ...                            ขท.ตรัง             ตรัง
# 2696        4348        100  ...                          ขท.กระบี่             ตรัง
# 2697        4349        100  ...              ขท.สุราษฎร์ธานีที่ 1      สุราษฎร์ธานี
# 2698        4350        100  ...  ขท.สุราษฎร์ธานีที่ 2 (กาญจนดิษฐ์)     สุราษฎร์ธานี
# ...

# %%
data_straffic62.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#       ทางหลวงสาย  ตอนควบคุม  ...  แขวงทางหลวง  จังหวัด
# 0          False      False  ...        False    False
# 1          False      False  ...        False    False
# 2          False      False  ...        False    False
# 3          False      False  ...        False    False
# 4          False      False  ...        False    False
# ...          ...        ...  ...          ...      ...
# 2695       False      False  ...        False    False
# 2696       False      False  ...        False    False
# 2697       False      False  ...        False    False
# 2698       False      False  ...        False    False
# 2699       False      False  ...        False    False
#
# [2700 rows x 20 columns]

# %%
data_straffic62.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง
# Out:
# ทางหลวงสาย                              False
# ตอนควบคุม                               False
# ชื่อสายทาง                              False
# จุดสำรวจ                                False
# รถยนต์นั่ง (ไม่เกิน 7 คน)               False
# รถยนต์นั่ง (เกิน 7 คน)                  False
# รถโดยสารขนาดเล็ก                        False
# รถโดยสารขนาดกลาง                        False
# รถโดยสารขนาดใหญ่                        False
#    รถบรรทุกขนาดเล็ก    ( 4 ล้อ)         False
# รถบรรทุกขนาด 2 เพลา  (6 ล้อ)            False
#      รถบรรทุกขนาด 3 เพลา (10 ล้อ)       False
#    รถบรรทุกพ่วง  (มากกว่า 3 เพลา)       False
#    รถบรรทุกกึ่งพ่วง (มากกว่า 3 เพลา)    False
# รวม                                     False
#    % ของยานยนต์หนัก                     False
# จักรยาน 2 ล้อ และ จักรยาน 3 ล้อ         False
# สามล้อเครื่องและจักรยานยนต์             False
# แขวงทางหลวง                             False
# จังหวัด                                 False
# dtype: bool

# %%
data_accident = pd.read_csv(os.path.join(path,'accident2020.csv')) # ไฟล์ที่เราต้องการ
data_accident # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#        ปีที่เกิดเหตุ วันที่เกิดเหตุ   เวลา  ... สภาพอากาศ   LATITUDE   LONGITUDE
# 0               2020       1/1/2020   0:05  ...    แจ่มใส   8.008887   99.390674
# 1               2020       1/1/2020   0:05  ...    แจ่มใส  15.650940   99.478422
# 2               2020       1/1/2020   0:15  ...    แจ่มใส  17.191475  102.454305
# 3               2020       1/1/2020   0:15  ...    แจ่มใส  13.861192  100.506757
# 4               2020       1/1/2020   0:20  ...    แจ่มใส  16.609966  100.997331
# ...              ...            ...    ...  ...       ...        ...         ...
# 21047           2020     31/12/2020  23:30  ...    แจ่มใส   6.975497  100.683499
# 21048           2020     31/12/2020  23:30  ...    แจ่มใส  16.921467   99.293404
# 21049           2020     31/12/2020  23:35  ...    แจ่มใส  14.620238  101.088225
# 21050           2020     31/12/2020  23:50  ...    แจ่มใส  11.306529   99.461932
# 21051           2020     31/12/2020  23:59  ...    แจ่มใส   8.795792   99.913208
#
# ...

# %%
data_accident.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#        ปีที่เกิดเหตุ  วันที่เกิดเหตุ   เวลา  ...  สภาพอากาศ  LATITUDE  LONGITUDE
# 0              False           False  False  ...      False     False      False
# 1              False           False  False  ...      False     False      False
# 2              False           False  False  ...      False     False      False
# 3              False           False  False  ...      False     False      False
# 4              False           False  False  ...      False     False      False
# ...              ...             ...    ...  ...        ...       ...        ...
# 21047          False           False  False  ...      False     False      False
# 21048          False           False  False  ...      False     False      False
# 21049          False           False  False  ...      False     False      False
# 21050          False           False  False  ...      False     False      False
# 21051          False           False  False  ...      False     False      False
#
# ...

# %%
data_accident.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง
# Out:
# ปีที่เกิดเหตุ                       False
# วันที่เกิดเหตุ                      False
# เวลา                                False
# วันที่รายงาน                        False
# เวลาที่รายงาน                       False
# ACC_CODE                            False
# หน่วยงาน                            False
# สายทาง                               True
# ก.ม.                                 True
# จังหวัด                              True
# รถคันที่ 1                           True
# บริเวณที่เกิดเหตุ/ลักษณะทาง          True
# มูลเหตุสันนิษฐาน                    False
# ลักษณะการเกิดอุบัติเหตุ             False
# จำนวนรถที่เกิดเหตุ (รวมคันที่ 1)    False
# จำนวนผู้เสียชีวิต                   False
# รวมจำนวนผู้บาดเจ็บ                  False
# สภาพอากาศ                           False
# LATITUDE                             True
# LONGITUDE                            True
# dtype: bool

# %%
data_accidentnomissing = data_accident.dropna()
data_accidentnomissing
# Out:
#        ปีที่เกิดเหตุ วันที่เกิดเหตุ   เวลา  ... สภาพอากาศ   LATITUDE   LONGITUDE
# 0               2020       1/1/2020   0:05  ...    แจ่มใส   8.008887   99.390674
# 1               2020       1/1/2020   0:05  ...    แจ่มใส  15.650940   99.478422
# 2               2020       1/1/2020   0:15  ...    แจ่มใส  17.191475  102.454305
# 4               2020       1/1/2020   0:20  ...    แจ่มใส  16.609966  100.997331
# 5               2020       1/1/2020   0:30  ...    แจ่มใส  17.205694  102.965832
# ...              ...            ...    ...  ...       ...        ...         ...
# 21047           2020     31/12/2020  23:30  ...    แจ่มใส   6.975497  100.683499
# 21048           2020     31/12/2020  23:30  ...    แจ่มใส  16.921467   99.293404
# 21049           2020     31/12/2020  23:35  ...    แจ่มใส  14.620238  101.088225
# 21050           2020     31/12/2020  23:50  ...    แจ่มใส  11.306529   99.461932
# 21051           2020     31/12/2020  23:59  ...    แจ่มใส   8.795792   99.913208
#
# ...

# %%
data_accidentnomissing.isnull()
# Out:
#        ปีที่เกิดเหตุ  วันที่เกิดเหตุ   เวลา  ...  สภาพอากาศ  LATITUDE  LONGITUDE
# 0              False           False  False  ...      False     False      False
# 1              False           False  False  ...      False     False      False
# 2              False           False  False  ...      False     False      False
# 4              False           False  False  ...      False     False      False
# 5              False           False  False  ...      False     False      False
# ...              ...             ...    ...  ...        ...       ...        ...
# 21047          False           False  False  ...      False     False      False
# 21048          False           False  False  ...      False     False      False
# 21049          False           False  False  ...      False     False      False
# 21050          False           False  False  ...      False     False      False
# 21051          False           False  False  ...      False     False      False
#
# ...

# %%
data_accidentnomissing.isnull().any()
# Out:
# ปีที่เกิดเหตุ                       False
# วันที่เกิดเหตุ                      False
# เวลา                                False
# วันที่รายงาน                        False
# เวลาที่รายงาน                       False
# ACC_CODE                            False
# หน่วยงาน                            False
# สายทาง                              False
# ก.ม.                                False
# จังหวัด                             False
# รถคันที่ 1                          False
# บริเวณที่เกิดเหตุ/ลักษณะทาง         False
# มูลเหตุสันนิษฐาน                    False
# ลักษณะการเกิดอุบัติเหตุ             False
# จำนวนรถที่เกิดเหตุ (รวมคันที่ 1)    False
# จำนวนผู้เสียชีวิต                   False
# รวมจำนวนผู้บาดเจ็บ                  False
# สภาพอากาศ                           False
# LATITUDE                            False
# LONGITUDE                           False
# dtype: bool

# %%
data_straffic60 = pd.read_csv(os.path.join(path,'straffic60.csv')) # ไฟล์ที่เราต้องการ
data_straffic62 = pd.read_csv(os.path.join(path,'straffic62.csv')) # ไฟล์ที่เราต้องการ

# %%
data_straffic60.shape
# Out:
# (2691, 20)

# %%
data_straffic62.shape
# Out:
# (2700, 20)

# %%
merged_table = data_straffic60.merge(data_straffic62,how='left',left_on='ทางหลวงสาย',right_on='ทางหลวงสาย')
merged_table
# Out:
#        ทางหลวงสาย  ...        จังหวัด_y
# 0               1  ...    กรุงเทพมหานคร
# 1               1  ...         ปทุมธานี
# 2               1  ...  พระนครศรีอยุธยา
# 3               1  ...  พระนครศรีอยุธยา
# 4               1  ...  พระนครศรีอยุธยา
# ...           ...  ...              ...
# 20376        4347  ...             ตรัง
# 20377        4348  ...             ตรัง
# 20378        4349  ...     สุราษฎร์ธานี
# 20379        4350  ...     สุราษฎร์ธานี
# 20380        4363  ...             ยะลา
#
# [20381 rows x 39 columns]
